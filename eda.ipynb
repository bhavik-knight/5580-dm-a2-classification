# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/car.csv')

# %%
df.shape
# Out:
# (1728, 7)

# %%
df.columns
# Out:
# Index(['price', 'maintenance', 'doors', 'seats', 'storage', 'safety',
#        'shouldBuy'],
#       dtype='object')

# %%
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
    print(df[col].unique())
    print()
# Out:
# price: 4 unique values
# ['vhigh' 'high' 'med' 'low']
#
# maintenance: 4 unique values
# ['vhigh' 'high' 'med' 'low']
#
# doors: 4 unique values
# ['2' '3' '4' '5more']
#
# seats: 3 unique values
# ['2' '4' 'more']
#
# storage: 3 unique values
# ['small' 'med' 'big']
#
# safety: 3 unique values
# ['low' 'med' 'high']
#
# shouldBuy: 4 unique values
# ['unacc' 'acc' 'vgood' 'good']

# %%
df.describe(include='all')
# Out:
#         price maintenance doors seats storage safety shouldBuy
# count    1728        1728  1728  1728    1728   1728      1728
# unique      4           4     4     3       3      3         4
# top     vhigh       vhigh     2     2   small    low     unacc
# freq      432         432   432   576     576    576      1210

# %%
df['shouldBuy'].value_counts().sort_index()
# Out:
# shouldBuy
# acc       384
# good       69
# unacc    1210
# vgood      65
# Name: count, dtype: int64

# %%
figure = plt.figure(figsize=(8, 6))
df['shouldBuy'].value_counts().sort_index().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of shouldBuy')
# Out:
# Text(0.5, 1.0, 'Distribution of shouldBuy')

# %%
price = pd.crosstab(df['price'], df['shouldBuy'])
maintenance = pd.crosstab(df['maintenance'], df['shouldBuy'])
doors = pd.crosstab(df['doors'], df['shouldBuy'])
seats = pd.crosstab(df['seats'], df['shouldBuy'])
storage = pd.crosstab(df['storage'], df['shouldBuy'])
safety = pd.crosstab(df['safety'], df['shouldBuy'])

# %%
seats
# Out:
# shouldBuy  acc  good  unacc  vgood
# seats
# 2            0     0    576      0
# 4          198    36    312     30
# more       186    33    322     35
